# %%
from pyspark.sql import SparkSession
import getpass 
username=getpass.getuser()
spark=SparkSession. \
    builder. \
    config('spark.ui.port','0'). \
    config("spark.sql.warehouse.dir", f"/user/itv009200/warehouse"). \
    config('spark.shuffle.useOldFetchProtocol', 'true'). \
    enableHiveSupport(). \
    master('yarn'). \
    getOrCreate()

# %%
spark.conf.set("spark.sql.unacceptable_rated_pts", 0)
spark.conf.set("spark.sql.very_bad_rated_pts", 100)
spark.conf.set("spark.sql.bad_rated_pts", 250)
spark.conf.set("spark.sql.good_rated_pts", 500)
spark.conf.set("spark.sql.very_good_rated_pts", 650)
spark.conf.set("spark.sql.excellent_rated_pts", 800)

# %%
spark.conf.set("spark.sql.unacceptable_grade_pts", 750)
spark.conf.set("spark.sql.very_bad_grade_pts", 1000)
spark.conf.set("spark.sql.bad_grade_pts", 1500)
spark.conf.set("spark.sql.good_grade_pts", 2000)
spark.conf.set("spark.sql.very_good_grade_pts", 2500)

# %%
bad_customer_data_final_df = spark.read \
.format("csv") \
.option("header", True) \
.option("inferSchema", True) \
.load("/public/trendytech/lendingclubproject/bad/bad_customer_data_final")

# %%
bad_customer_data_final_df.createOrReplaceTempView("bad_data_customer")

# %%
spark.sql("select * from bad_data_customer limit 10").show()
# Out:
# +--------------------+
# |           member_id|
# +--------------------+
# |514da6011e2f772fb...|
# |d3125d00da326895a...|
# |4e9cc2faea777e410...|
# |8d42ec724248a79d2...|
# |c14309ba2311e430d...|
# |d9ce4046daf599732...|
# |e0ecccbcb94183be6...|
# |fecada6499caf7a4d...|
# |62d93eb316a3eacf4...|
# |e757d51dddd8fa34e...|
# +--------------------+

# %%
ph_df = spark.sql("select c.member_id, \
   case \
   when p.last_payment_amount < (c.monthly_installment * 0.5) then ${spark.sql.very_bad_rated_pts} \
   when p.last_payment_amount >= (c.monthly_installment * 0.5) and p.last_payment_amount < c.monthly_installment then ${spark.sql.very_bad_rated_pts} \
   when (p.last_payment_amount = (c.monthly_installment)) then ${spark.sql.good_rated_pts} \
   when p.last_payment_amount > (c.monthly_installment) and p.last_payment_amount <= (c.monthly_installment * 1.50) then ${spark.sql.very_good_rated_pts} \
   when p.last_payment_amount > (c.monthly_installment * 1.50) then ${spark.sql.excellent_rated_pts} \
   else ${spark.sql.unacceptable_rated_pts} \
   end as last_payment_pts, \
   case \
   when p.total_payment_received >= (c.funded_amount * 0.50) then ${spark.sql.very_good_rated_pts} \
   when p.total_payment_received < (c.funded_amount * 0.50) and p.total_payment_received > 0 then ${spark.sql.good_rated_pts} \
   when p.total_payment_received = 0 or (p.total_payment_received) is null then ${spark.sql.unacceptable_rated_pts} \
   end as total_payment_pts \
from itv009200_lending_club.loans_repayments_new p \
inner join itv009200_lending_club_new.loans1 c on c.loan_id = p.loan_id where member_id NOT IN (select member_id from bad_data_customer)")

# %%
ph_df.createOrReplaceTempView("ph_pts")

# %%
spark.sql("select * from ph_pts")
# Out:
# +--------------------+----------------+-----------------+
# |           member_id|last_payment_pts|total_payment_pts|
# +--------------------+----------------+-----------------+
# |dcec9334e70f1cc95...|             800|              650|
# |fc58ca61f51f9dcac...|             500|              650|
# |2fb62a6ca51063b11...|             500|              650|
# |488268a5531951622...|             800|              650|
# |ade6026208e48f5f9...|             500|              650|
# |7c8b0ca6acddfaeb1...|             800|              650|
# |a707b7fe7c38bad65...|             800|              650|
# |1df639cddea30c288...|             800|              650|
# |22d67005e12d8726d...|             500|              650|
# |009cf312bd46551b4...|             500|              650|
# |2d995d383622fa80e...|             500|              650|
# |88b97663d2562f239...|             500|              650|
# |097d871ba6f21ee37...|             500|              650|
# |82e698108e1b8b88a...|             500|              650|
# |9e89f004a01479234...|             500|              650|
# |28ea534e78570f8d1...|             800|              650|
# |27a6888d24e06f6e2...|             500|              650|
# |c0d144ae7ab17c793...|             500|              500|
# |56d1102515f7d6a32...|             800|              650|
# |ba484052baf1e604c...|             800|              650|
# +--------------------+----------------+-----------------+
# only showing top 20 rows

# %%
ldh_ph_df = spark.sql(
    "select p.*, \
        CASE \
        WHEN d.delinq_2yrs = 0 THEN ${spark.sql.excellent_rated_pts} \
        WHEN d.delinq_2yrs BETWEEN 1 AND 2 THEN ${spark.sql.bad_rated_pts} \
        WHEN d.delinq_2yrs BETWEEN 3 AND 5 THEN ${spark.sql.very_bad_rated_pts} \
        WHEN d.delinq_2yrs > 5 OR d.delinq_2yrs IS NULL THEN ${spark.sql.unacceptable_grade_pts} \
        END AS delinq_pts, \
        CASE \
        WHEN l.pub_rec = 0 THEN ${spark.sql.excellent_rated_pts} \
        WHEN l.pub_rec BETWEEN 1 AND 2 THEN ${spark.sql.bad_rated_pts} \
        WHEN l.pub_rec BETWEEN 3 AND 5 THEN ${spark.sql.very_bad_rated_pts} \
        WHEN l.pub_rec > 5 OR l.pub_rec IS NULL THEN ${spark.sql.very_bad_rated_pts} \
        END AS public_records_pts, \
        CASE \
        WHEN l.pub_rec_bankruptcies = 0 THEN ${spark.sql.excellent_rated_pts} \
        WHEN l.pub_rec_bankruptcies BETWEEN 1 AND 2 THEN ${spark.sql.bad_rated_pts} \
        WHEN l.pub_rec_bankruptcies BETWEEN 3 AND 5 THEN ${spark.sql.very_bad_rated_pts} \
        WHEN l.pub_rec_bankruptcies > 5 OR l.pub_rec_bankruptcies IS NULL THEN ${spark.sql.very_bad_rated_pts} \
        END AS public_bankruptcies_pts, \
        CASE \
        WHEN l.inq_last_6mths = 0 THEN ${spark.sql.excellent_rated_pts} \
        WHEN l.inq_last_6mths BETWEEN 1 AND 2 THEN ${spark.sql.bad_rated_pts} \
        WHEN l.inq_last_6mths BETWEEN 3 AND 5 THEN ${spark.sql.very_bad_rated_pts} \
        WHEN l.inq_last_6mths > 5 OR l.inq_last_6mths IS NULL THEN ${spark.sql.unacceptable_rated_pts} \
        END AS enq_pts \
        FROM itv009200_lending_club_new.loans_defaulters_detail_rec_enq_new l \
        INNER JOIN itv009200_lending_club_new.loans_defaulters_delinq_new d ON d.member_id = l.member_id  \
        INNER JOIN ph_pts p ON p.member_id = l.member_id where l.member_id NOT IN (select member_id from bad_data_customer)")

ldh_ph_df.show()
# Out:
# +--------------------+----------------+-----------------+----------+------------------+-----------------------+-------+
# |           member_id|last_payment_pts|total_payment_pts|delinq_pts|public_records_pts|public_bankruptcies_pts|enq_pts|
# +--------------------+----------------+-----------------+----------+------------------+-----------------------+-------+
# |000c8875b71a6b47c...|             800|              650|       250|               800|                    800|    800|
# |003769d7f54c7859e...|             500|              500|       250|               800|                    800|    800|
# |003e1e6cbd2920bbb...|             500|              650|       250|               250|                    250|    800|
# |004017b21bd4d6271...|             100|              650|       750|               800|                    800|    800|
# |005b4c3db3fce07dc...|             500|              650|       250|               250|                    800|    250|
# |00710707c563c2119...|             800|              650|       250|               800|                    800|    800|
# |007da79904f69970d...|             800|              650|       250|               800|                    800|    800|
# |00f435a80d0440ece...|             500|              500|       100|               800|                    800|    800|
# |00fc2ae3ffb1213e4...|             650|              650|       250|               800|                    800|    800|
# |00fc8144cb210ba8c...|             500|              650|       250|               250|                    250|    800|
# |01121d7f3f6f27495...|             800|              650|       250|               800|                    800|    800|
# |0112e15adaf0c0029...|             500|              650|       250|               800|                    800|    800|
# |017ce564dc0d6f975...|             500|              500|       250|               800|                    800|    250|
# |017d1fd3d6169ee29...|             800|              500|       800|               250|                    250|    250|
# |018a82c47453bf02d...|             100|              650|       800|               250|                    800|    800|
# |018b0f369c2d63913...|             100|              650|       800|               800|                    800|    100|
# |01b39bf7187932c4a...|             800|              650|       250|               250|                    800|    800|
# |01d0686210978f0a7...|             500|              500|       750|               800|                    800|    800|
# |01d0c48835e969a01...|             500|              500|       800|               800|                    800|    250|
# |01ef63fce64f41ef9...|             800|              650|       250|               800|                    800|    800|
# +--------------------+----------------+-----------------+----------+------------------+-----------------------+-------+
# only showing top 20 rows

# %%
ldh_ph_df
# Out:
# +--------------------+----------------+-----------------+----------+------------------+-----------------------+-------+
# |           member_id|last_payment_pts|total_payment_pts|delinq_pts|public_records_pts|public_bankruptcies_pts|enq_pts|
# +--------------------+----------------+-----------------+----------+------------------+-----------------------+-------+
# |000c8875b71a6b47c...|             800|              650|       250|               800|                    800|    800|
# |003769d7f54c7859e...|             500|              500|       250|               800|                    800|    800|
# |003e1e6cbd2920bbb...|             500|              650|       250|               250|                    250|    800|
# |004017b21bd4d6271...|             100|              650|       750|               800|                    800|    800|
# |005b4c3db3fce07dc...|             500|              650|       250|               250|                    800|    250|
# |00710707c563c2119...|             800|              650|       250|               800|                    800|    800|
# |007da79904f69970d...|             800|              650|       250|               800|                    800|    800|
# |00f435a80d0440ece...|             500|              500|       100|               800|                    800|    800|
# |00fc2ae3ffb1213e4...|             650|              650|       250|               800|                    800|    800|
# |00fc8144cb210ba8c...|             500|              650|       250|               250|                    250|    800|
# |01121d7f3f6f27495...|             800|              650|       250|               800|                    800|    800|
# |0112e15adaf0c0029...|             500|              650|       250|               800|                    800|    800|
# |017ce564dc0d6f975...|             500|              500|       250|               800|                    800|    250|
# |017d1fd3d6169ee29...|             800|              500|       800|               250|                    250|    250|
# |018a82c47453bf02d...|             100|              650|       800|               250|                    800|    800|
# |018b0f369c2d63913...|             100|              650|       800|               800|                    800|    100|
# |01b39bf7187932c4a...|             800|              650|       250|               250|                    800|    800|
# |01d0686210978f0a7...|             500|              500|       750|               800|                    800|    800|
# |01d0c48835e969a01...|             500|              500|       800|               800|                    800|    250|
# |01ef63fce64f41ef9...|             800|              650|       250|               800|                    800|    800|
# +--------------------+----------------+-----------------+----------+------------------+-----------------------+-------+
# only showing top 20 rows

# %%
ldh_ph_df.createOrReplaceTempView("ldh_ph_pts")

# %%
spark.sql("select * from ldh_ph_pts")
# Out:
# +--------------------+----------------+-----------------+----------+------------------+-----------------------+-------+
# |           member_id|last_payment_pts|total_payment_pts|delinq_pts|public_records_pts|public_bankruptcies_pts|enq_pts|
# +--------------------+----------------+-----------------+----------+------------------+-----------------------+-------+
# |000c8875b71a6b47c...|             800|              650|       250|               800|                    800|    800|
# |003769d7f54c7859e...|             500|              500|       250|               800|                    800|    800|
# |003e1e6cbd2920bbb...|             500|              650|       250|               250|                    250|    800|
# |004017b21bd4d6271...|             100|              650|       750|               800|                    800|    800|
# |005b4c3db3fce07dc...|             500|              650|       250|               250|                    800|    250|
# |00710707c563c2119...|             800|              650|       250|               800|                    800|    800|
# |007da79904f69970d...|             800|              650|       250|               800|                    800|    800|
# |00f435a80d0440ece...|             500|              500|       100|               800|                    800|    800|
# |00fc2ae3ffb1213e4...|             650|              650|       250|               800|                    800|    800|
# |00fc8144cb210ba8c...|             500|              650|       250|               250|                    250|    800|
# |01121d7f3f6f27495...|             800|              650|       250|               800|                    800|    800|
# |0112e15adaf0c0029...|             500|              650|       250|               800|                    800|    800|
# |017ce564dc0d6f975...|             500|              500|       250|               800|                    800|    250|
# |017d1fd3d6169ee29...|             800|              500|       800|               250|                    250|    250|
# |018a82c47453bf02d...|             100|              650|       800|               250|                    800|    800|
# |018b0f369c2d63913...|             100|              650|       800|               800|                    800|    100|
# |01b39bf7187932c4a...|             800|              650|       250|               250|                    800|    800|
# |01d0686210978f0a7...|             500|              500|       750|               800|                    800|    800|
# |01d0c48835e969a01...|             500|              500|       800|               800|                    800|    250|
# |01ef63fce64f41ef9...|             800|              650|       250|               800|                    800|    800|
# +--------------------+----------------+-----------------+----------+------------------+-----------------------+-------+
# only showing top 20 rows

# %%
fh_ldh_ph_df = spark.sql("select ldef.*, \
   CASE \
   WHEN LOWER(l.loan_status) LIKE '%fully paid%' THEN ${spark.sql.excellent_rated_pts} \
   WHEN LOWER(l.loan_status) LIKE '%current%' THEN ${spark.sql.good_rated_pts} \
   WHEN LOWER(l.loan_status) LIKE '%in grace period%' THEN ${spark.sql.bad_rated_pts} \
   WHEN LOWER(l.loan_status) LIKE '%late (16-30 days)%' OR LOWER(l.loan_status) LIKE '%late (31-120 days)%' THEN ${spark.sql.very_bad_rated_pts} \
   WHEN LOWER(l.loan_status) LIKE '%charged off%' THEN ${spark.sql.unacceptable_rated_pts} \
   else ${spark.sql.unacceptable_rated_pts} \
   END AS loan_status_pts, \
   CASE \
   WHEN LOWER(a.home_ownership) LIKE '%own' THEN ${spark.sql.excellent_rated_pts} \
   WHEN LOWER(a.home_ownership) LIKE '%rent' THEN ${spark.sql.good_rated_pts} \
   WHEN LOWER(a.home_ownership) LIKE '%mortgage' THEN ${spark.sql.bad_rated_pts} \
   WHEN LOWER(a.home_ownership) LIKE '%any' OR LOWER(a.home_ownership) IS NULL THEN ${spark.sql.very_bad_rated_pts} \
   END AS home_pts, \
   CASE \
   WHEN l.funded_amount <= (a.total_high_credit_limit * 0.10) THEN ${spark.sql.excellent_rated_pts} \
   WHEN l.funded_amount > (a.total_high_credit_limit * 0.10) AND l.funded_amount <= (a.total_high_credit_limit * 0.20) THEN ${spark.sql.very_good_rated_pts} \
   WHEN l.funded_amount > (a.total_high_credit_limit * 0.20) AND l.funded_amount <= (a.total_high_credit_limit * 0.30) THEN ${spark.sql.good_rated_pts} \
   WHEN l.funded_amount > (a.total_high_credit_limit * 0.30) AND l.funded_amount <= (a.total_high_credit_limit * 0.50) THEN ${spark.sql.bad_rated_pts} \
   WHEN l.funded_amount > (a.total_high_credit_limit * 0.50) AND l.funded_amount <= (a.total_high_credit_limit * 0.70) THEN ${spark.sql.very_bad_rated_pts} \
   WHEN l.funded_amount > (a.total_high_credit_limit * 0.70) THEN ${spark.sql.unacceptable_rated_pts} \
   else ${spark.sql.unacceptable_rated_pts} \
   END AS credit_limit_pts, \
   CASE \
   WHEN (a.grade) = 'A' and (a.sub_grade)='A1' THEN ${spark.sql.excellent_rated_pts} \
   WHEN (a.grade) = 'A' and (a.sub_grade)='A2' THEN (${spark.sql.excellent_rated_pts} * 0.95) \
   WHEN (a.grade) = 'A' and (a.sub_grade)='A3' THEN (${spark.sql.excellent_rated_pts} * 0.90) \
   WHEN (a.grade) = 'A' and (a.sub_grade)='A4' THEN (${spark.sql.excellent_rated_pts} * 0.85) \
   WHEN (a.grade) = 'A' and (a.sub_grade)='A5' THEN (${spark.sql.excellent_rated_pts} * 0.80) \
   WHEN (a.grade) = 'B' and (a.sub_grade)='B1' THEN (${spark.sql.very_good_rated_pts}) \
   WHEN (a.grade) = 'B' and (a.sub_grade)='B2' THEN (${spark.sql.very_good_rated_pts} * 0.95) \
   WHEN (a.grade) = 'B' and (a.sub_grade)='B3' THEN (${spark.sql.very_good_rated_pts} * 0.90) \
   WHEN (a.grade) = 'B' and (a.sub_grade)='B4' THEN (${spark.sql.very_good_rated_pts} * 0.85) \
   WHEN (a.grade) = 'B' and (a.sub_grade)='B5' THEN (${spark.sql.very_good_rated_pts} * 0.80) \
   WHEN (a.grade) = 'C' and (a.sub_grade)='C1' THEN (${spark.sql.good_rated_pts}) \
   WHEN (a.grade) = 'C' and (a.sub_grade)='C2' THEN (${spark.sql.good_rated_pts} * 0.95) \
   WHEN (a.grade) = 'C' and (a.sub_grade)='C3' THEN (${spark.sql.good_rated_pts} * 0.90) \
   WHEN (a.grade) = 'C' and (a.sub_grade)='C4' THEN (${spark.sql.good_rated_pts} * 0.85) \
   WHEN (a.grade) = 'C' and (a.sub_grade)='C5' THEN (${spark.sql.good_rated_pts} * 0.80) \
   WHEN (a.grade) = 'D' and (a.sub_grade)='D1' THEN (${spark.sql.bad_rated_pts}) \
   WHEN (a.grade) = 'D' and (a.sub_grade)='D2' THEN (${spark.sql.bad_rated_pts} * 0.95) \
   WHEN (a.grade) = 'D' and (a.sub_grade)='D3' THEN (${spark.sql.bad_rated_pts} * 0.90) \
   WHEN (a.grade) = 'D' and (a.sub_grade)='D4' THEN (${spark.sql.bad_rated_pts} * 0.85) \
   WHEN (a.grade) = 'D' and (a.sub_grade)='D5' THEN (${spark.sql.bad_rated_pts} * 0.80) \
   WHEN (a.grade) = 'E' and (a.sub_grade)='E1' THEN (${spark.sql.very_bad_rated_pts}) \
   WHEN (a.grade) = 'E' and (a.sub_grade)='E2' THEN (${spark.sql.very_bad_rated_pts} * 0.95) \
   WHEN (a.grade) = 'E' and (a.sub_grade)='E3' THEN (${spark.sql.very_bad_rated_pts} * 0.90) \
   WHEN (a.grade) = 'E' and (a.sub_grade)='E4' THEN (${spark.sql.very_bad_rated_pts} * 0.85) \
   WHEN (a.grade) = 'E' and (a.sub_grade)='E5' THEN (${spark.sql.very_bad_rated_pts} * 0.80) \
   WHEN (a.grade) in ('F', 'G') THEN (${spark.sql.unacceptable_rated_pts}) \
   END AS grade_pts \
   FROM ldh_ph_pts ldef \
   INNER JOIN itv009200_lending_club_new.loans l ON ldef.member_id = l.member_id \
   INNER JOIN itv009200_lending_club_new.customers_new a ON a.member_id = ldef.member_id where ldef.member_id NOT IN (select member_id from bad_data_customer)")

# %%
fh_ldh_ph_df.createOrReplaceTempView("fh_ldh_ph_pts")

# %%
loan_score = spark.sql("SELECT member_id, \
((last_payment_pts+total_payment_pts)*0.20) as payment_history_pts, \
((delinq_pts + public_records_pts + public_bankruptcies_pts + enq_pts) * 0.45) as defaulters_history_pts, \
((loan_status_pts + home_pts + credit_limit_pts + grade_pts)*0.35) as financial_health_pts \
FROM fh_ldh_ph_pts")

# %%
loan_score.show()
# Out:
# +--------------------+-------------------+----------------------+--------------------+
# |           member_id|payment_history_pts|defaulters_history_pts|financial_health_pts|
# +--------------------+-------------------+----------------------+--------------------+
# |000c8875b71a6b47c...|             290.00|               1192.50|            885.5000|
# |003769d7f54c7859e...|             200.00|               1192.50|            402.5000|
# |003e1e6cbd2920bbb...|             230.00|                697.50|            766.5000|
# |004017b21bd4d6271...|             150.00|               1417.50|            822.5000|
# |005b4c3db3fce07dc...|             230.00|                697.50|            619.5000|
# |00710707c563c2119...|             290.00|               1192.50|            829.5000|
# |007da79904f69970d...|             290.00|               1192.50|            822.5000|
# |00f435a80d0440ece...|             200.00|               1125.00|            708.7500|
# |00fc2ae3ffb1213e4...|             260.00|               1192.50|            752.5000|
# |00fc8144cb210ba8c...|             230.00|                697.50|            717.5000|
# |01121d7f3f6f27495...|             290.00|               1192.50|            863.6250|
# |0112e15adaf0c0029...|             230.00|               1192.50|            595.0000|
# |017ce564dc0d6f975...|             200.00|                945.00|            591.5000|
# |017d1fd3d6169ee29...|             260.00|                697.50|            694.7500|
# |018a82c47453bf02d...|             150.00|               1192.50|            948.5000|
# |018b0f369c2d63913...|             150.00|               1125.00|            735.0000|
# |01b39bf7187932c4a...|             290.00|                945.00|            939.7500|
# |01d0686210978f0a7...|             200.00|               1417.50|            619.5000|
# |01d0c48835e969a01...|             200.00|               1192.50|            262.5000|
# |01ef63fce64f41ef9...|             290.00|               1192.50|            875.8750|
# +--------------------+-------------------+----------------------+--------------------+
# only showing top 20 rows

# %%
final_loan_score = loan_score.withColumn('loan_score', loan_score.payment_history_pts + loan_score.defaulters_history_pts + loan_score.financial_health_pts)

# %%
final_loan_score.createOrReplaceTempView("loan_score_eval")

# %%
loan_score_final = spark.sql("select ls.*, \
case \
WHEN loan_score > ${spark.sql.very_good_grade_pts} THEN 'A' \
WHEN loan_score <= ${spark.sql.very_good_grade_pts} AND loan_score > ${spark.sql.good_grade_pts} THEN 'B' \
WHEN loan_score <= ${spark.sql.good_grade_pts} AND loan_score > ${spark.sql.bad_grade_pts} THEN 'C' \
WHEN loan_score <= ${spark.sql.bad_grade_pts} AND loan_score  > ${spark.sql.very_bad_grade_pts} THEN 'D' \
WHEN loan_score <= ${spark.sql.very_bad_grade_pts} AND loan_score > ${spark.sql.unacceptable_grade_pts} THEN 'E'  \
WHEN loan_score <= ${spark.sql.unacceptable_grade_pts} THEN 'F' \
end as loan_final_grade \
from loan_score_eval ls")

# %%
loan_score_final.show()
# Out:
# +--------------------+-------------------+----------------------+--------------------+----------+----------------+
# |           member_id|payment_history_pts|defaulters_history_pts|financial_health_pts|loan_score|loan_final_grade|
# +--------------------+-------------------+----------------------+--------------------+----------+----------------+
# |000c8875b71a6b47c...|             290.00|               1192.50|            885.5000| 2368.0000|               B|
# |003769d7f54c7859e...|             200.00|               1192.50|            402.5000| 1795.0000|               C|
# |003e1e6cbd2920bbb...|             230.00|                697.50|            766.5000| 1694.0000|               C|
# |004017b21bd4d6271...|             150.00|               1417.50|            822.5000| 2390.0000|               B|
# |005b4c3db3fce07dc...|             230.00|                697.50|            619.5000| 1547.0000|               C|
# |00710707c563c2119...|             290.00|               1192.50|            829.5000| 2312.0000|               B|
# |007da79904f69970d...|             290.00|               1192.50|            822.5000| 2305.0000|               B|
# |00f435a80d0440ece...|             200.00|               1125.00|            708.7500| 2033.7500|               B|
# |00fc2ae3ffb1213e4...|             260.00|               1192.50|            752.5000| 2205.0000|               B|
# |00fc8144cb210ba8c...|             230.00|                697.50|            717.5000| 1645.0000|               C|
# |01121d7f3f6f27495...|             290.00|               1192.50|            863.6250| 2346.1250|               B|
# |0112e15adaf0c0029...|             230.00|               1192.50|            595.0000| 2017.5000|               B|
# |017ce564dc0d6f975...|             200.00|                945.00|            591.5000| 1736.5000|               C|
# |017d1fd3d6169ee29...|             260.00|                697.50|            694.7500| 1652.2500|               C|
# |018a82c47453bf02d...|             150.00|               1192.50|            948.5000| 2291.0000|               B|
# |018b0f369c2d63913...|             150.00|               1125.00|            735.0000| 2010.0000|               B|
# |01b39bf7187932c4a...|             290.00|                945.00|            939.7500| 2174.7500|               B|
# |01d0686210978f0a7...|             200.00|               1417.50|            619.5000| 2237.0000|               B|
# |01d0c48835e969a01...|             200.00|               1192.50|            262.5000| 1655.0000|               C|
# |01ef63fce64f41ef9...|             290.00|               1192.50|            875.8750| 2358.3750|               B|
# +--------------------+-------------------+----------------------+--------------------+----------+----------------+
# only showing top 20 rows

# %%
loan_score_final.createOrReplaceTempView("loan_final_table")

# %%
spark.sql("select * from loan_final_table where loan_final_grade in ('C')")
# Out:
# +--------------------+-------------------+----------------------+--------------------+----------+----------------+
# |           member_id|payment_history_pts|defaulters_history_pts|financial_health_pts|loan_score|loan_final_grade|
# +--------------------+-------------------+----------------------+--------------------+----------+----------------+
# |003769d7f54c7859e...|             200.00|               1192.50|            402.5000| 1795.0000|               C|
# |003e1e6cbd2920bbb...|             230.00|                697.50|            766.5000| 1694.0000|               C|
# |005b4c3db3fce07dc...|             230.00|                697.50|            619.5000| 1547.0000|               C|
# |00fc8144cb210ba8c...|             230.00|                697.50|            717.5000| 1645.0000|               C|
# |017ce564dc0d6f975...|             200.00|                945.00|            591.5000| 1736.5000|               C|
# |017d1fd3d6169ee29...|             260.00|                697.50|            694.7500| 1652.2500|               C|
# |01d0c48835e969a01...|             200.00|               1192.50|            262.5000| 1655.0000|               C|
# |02f69de1384fcf78c...|             150.00|                945.00|            864.5000| 1959.5000|               C|
# |032503cc8f86dea72...|             200.00|                945.00|            647.5000| 1792.5000|               C|
# |035a8c46279041682...|             230.00|               1192.50|            507.5000| 1930.0000|               C|
# |03c814d2820c4f5ca...|             200.00|               1125.00|            573.1250| 1898.1250|               C|
# |0401f0eff7d188d40...|             200.00|                945.00|            612.5000| 1757.5000|               C|
# |044605ddb5536b14d...|             290.00|               1192.50|            481.2500| 1963.7500|               C|
# |047e58a29eaf50dea...|             290.00|                945.00|            675.5000| 1910.5000|               C|
# |049af7d32085b507b...|             230.00|                945.00|            691.2500| 1866.2500|               C|
# |04a56cd37ddf106b4...|             200.00|                945.00|            507.5000| 1652.5000|               C|
# |0507405ffa21cc80b...|             150.00|                945.00|            813.7500| 1908.7500|               C|
# |053c3d4498bc0d4d6...|             260.00|                945.00|            682.5000| 1887.5000|               C|
# |056724e48de8fab2f...|             150.00|               1440.00|            311.5000| 1901.5000|               C|
# |057a544d7370db315...|             200.00|                945.00|            794.5000| 1939.5000|               C|
# +--------------------+-------------------+----------------------+--------------------+----------+----------------+
# only showing top 20 rows

# %%
spark.sql("select count(*) from loan_final_table")
# Out:
# +--------+
# |count(1)|
# +--------+
# |  482842|
# +--------+

# %%
loan_score_final.write \
.format("parquet") \
.mode("overwrite") \
.option("path", "/user/itv009200/lendingclubproject/processed/loan_score") \
.save()

# %%
spark.stop()

# %%
# !hadoop fs -ls /user/itv009200/lendingclubproject/processed/loan_score
# Out:
# Found 201 items
# -rw-r--r--   3 itv009200 supergroup          0 2024-03-15 09:29 /user/itv009200/lendingclubproject/processed/loan_score/_SUCCESS
# -rw-r--r--   3 itv009200 supergroup     169536 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00000-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     175834 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00001-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171196 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00002-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170342 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00003-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     166370 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00004-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     172810 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00005-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173646 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00006-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171357 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00007-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173970 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00008-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     172408 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00009-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     169563 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00010-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173938 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00011-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     166319 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00012-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     176976 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00013-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     174548 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00014-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     168436 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00015-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171892 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00016-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     176540 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00017-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171486 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00018-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     172637 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00019-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173241 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00020-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     167661 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00021-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     172488 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00022-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     177822 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00023-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     166620 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00024-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     175884 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00025-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     172256 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00026-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170707 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00027-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170067 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00028-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173387 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00029-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173944 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00030-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     177957 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00031-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     167085 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00032-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     176292 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00033-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171831 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00034-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     172180 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00035-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     168887 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00036-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170368 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00037-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170253 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00038-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     174232 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00039-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     172475 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00040-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     168657 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00041-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     172933 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00042-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171402 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00043-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     175703 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00044-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     168996 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00045-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     166158 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00046-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     166283 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00047-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171223 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00048-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     169076 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00049-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171774 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00050-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170109 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00051-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173641 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00052-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170377 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00053-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     167356 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00054-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     169262 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00055-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170234 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00056-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171860 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00057-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     175674 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00058-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     167569 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00059-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     175114 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00060-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170173 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00061-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     166440 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00062-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     169833 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00063-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     176152 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00064-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170714 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00065-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173404 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00066-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     169159 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00067-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170482 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00068-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     181003 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00069-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     174603 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00070-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     176922 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00071-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     163389 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00072-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     174512 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00073-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173480 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00074-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     178408 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00075-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     176458 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00076-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     167553 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00077-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     169643 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00078-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170286 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00079-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     168704 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00080-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     163874 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00081-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     169468 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00082-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170500 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00083-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170829 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00084-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     167960 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00085-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     168411 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00086-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170090 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00087-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170579 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00088-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170697 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00089-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171880 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00090-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     172985 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00091-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173510 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00092-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170807 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00093-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     166209 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00094-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     166382 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00095-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     164506 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00096-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     174208 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00097-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170901 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00098-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     174083 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00099-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173283 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00100-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170184 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00101-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170219 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00102-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170208 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00103-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171485 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00104-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173555 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00105-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170603 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00106-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     169750 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00107-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170960 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00108-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     172545 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00109-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     169149 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00110-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     176121 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00111-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173216 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00112-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     165531 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00113-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     175887 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00114-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     174040 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00115-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171110 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00116-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173380 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00117-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     174941 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00118-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     168189 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00119-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171086 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00120-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     166497 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00121-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     172121 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00122-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     176190 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00123-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     172348 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00124-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     178690 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00125-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171652 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00126-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171490 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00127-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     172782 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00128-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170406 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00129-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170129 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00130-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171470 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00131-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173241 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00132-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     165972 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00133-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     174735 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00134-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     179359 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00135-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     174176 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00136-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     167655 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00137-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     166468 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00138-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     174948 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00139-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     164456 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00140-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     175281 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00141-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     168683 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00142-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     167257 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00143-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     166342 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00144-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     165610 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00145-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     176425 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00146-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171800 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00147-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     174788 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00148-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     176482 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00149-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171355 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00150-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     176255 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00151-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     169454 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00152-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171276 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00153-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171000 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00154-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     172491 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00155-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     178272 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00156-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     167815 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00157-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     162573 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00158-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     167989 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00159-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170584 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00160-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     169108 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00161-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     174923 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00162-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173104 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00163-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     167008 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00164-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     175845 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00165-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     172015 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00166-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     169832 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00167-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171334 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00168-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     166511 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00169-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     167565 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00170-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171269 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00171-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     166014 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00172-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173758 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00173-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173634 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00174-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     177099 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00175-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     167173 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00176-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     176429 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00177-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     168636 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00178-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173658 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00179-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     166216 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00180-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     172567 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00181-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     177804 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00182-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     168266 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00183-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     178515 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00184-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     174928 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00185-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173765 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00186-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     176929 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00187-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     173213 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00188-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     171927 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00189-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     165001 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00190-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     169340 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00191-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     175977 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00192-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170718 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00193-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     174256 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00194-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170696 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00195-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170181 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00196-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     165357 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00197-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     172342 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00198-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet
# -rw-r--r--   3 itv009200 supergroup     170071 2024-03-15 09:28 /user/itv009200/lendingclubproject/processed/loan_score/part-00199-99be8d59-3c54-4368-b7fd-ad798e5eac8f-c000.snappy.parquet

# %%
read = spark.read \
.format("parquet") \
.load("/user/itv009200/lendingclubproject/processed/loan_score")

# %%
read.show()
# Out:
# +--------------------+-------------------+----------------------+--------------------+----------+----------------+
# |           member_id|payment_history_pts|defaulters_history_pts|financial_health_pts|loan_score|loan_final_grade|
# +--------------------+-------------------+----------------------+--------------------+----------+----------------+
# |003f2e02514aea690...|             200.00|               1192.50|            560.8750| 1953.3750|               C|
# |0054773d508bed06e...|             260.00|               1192.50|            381.5000| 1834.0000|               C|
# |008054a22f213faad...|             230.00|                945.00|            469.0000| 1644.0000|               C|
# |0081d6dbdc1913583...|             150.00|               1192.50|            780.5000| 2123.0000|               B|
# |00eb5a401ffc73731...|             290.00|               1417.50|            444.5000| 2152.0000|               B|
# |01156c673e503a06c...|             200.00|               1170.00|            787.5000| 2157.5000|               B|
# |0128d1ccea36d98f6...|             200.00|               1125.00|            822.5000| 2147.5000|               B|
# |01301963068f6ff92...|             290.00|               1125.00|            630.0000| 2045.0000|               B|
# |014de1672392b087e...|             290.00|               1192.50|            682.5000| 2165.0000|               B|
# |0164e30c7654709c8...|             150.00|               1192.50|            780.5000| 2123.0000|               B|
# |0173250e47fd97f25...|             290.00|                945.00|            796.2500| 2031.2500|               B|
# |0176b710a5778c052...|             230.00|                945.00|            700.0000| 1875.0000|               C|
# |01fc20009c9d2e397...|             150.00|               1192.50|            350.0000| 1692.5000|               C|
# |0207d1d81b7f0a2a2...|             290.00|               1192.50|            770.0000| 2252.5000|               B|
# |02093d51afd3410bd...|             230.00|                945.00|            718.3750| 1893.3750|               C|
# |020dc30e4035f3344...|             200.00|                945.00|            529.3750| 1674.3750|               C|
# |02373defacf2fb03f...|             150.00|               1192.50|            788.3750| 2130.8750|               B|
# |023c11157d0b2c17f...|             200.00|               1192.50|            656.2500| 2048.7500|               B|
# |023eb7af9ff9afb2f...|             150.00|                877.50|            595.0000| 1622.5000|               C|
# |024b9af0631808dcf...|             290.00|               1192.50|            864.5000| 2347.0000|               B|
# +--------------------+-------------------+----------------------+--------------------+----------+----------------+
# only showing top 20 rows
